# %% [markdown]
# # Tristan Beckmann
#
# # 2023SP Computer Prog for Liberal Arts (CS-150-01)
# ## Programming Assignment 7 - Version 1
# ### Spring 2023

# %%
import math
class calc():
    def __init__(self, input1, input2):
        self.input1=input1
        self.input2=input2
   
    def addition(num1, num2):
        print(f'Addition= {num1+num2}')
        
    def sub(num1,num2):
        print(f'Subtraction= {num1-num2}')
        
    def mult(num1,num2):
        print(f'Multiplication={num1*num2}')
    
    def div(num1,num2):
        print(f'Division= {num1/num2}')
    
    def sin(num1):
        print(f'The sin= {math.sin(num1)}')
    def cosine(num1):
        print(f'The cosine= {math.cos(num1)}')
    def tangent(num1):
        print(f'The tangent= {math.tan(num1)}')
    def secant(num1):
        print(f'The secant= {1/math.sin(num1)}')
    def cosecant(num1):
        print(f'The cosecant= {1/math.cos(num1)}')
    def cotan(num1):
        print(f'The contangent= {1/math.tan(num1)}')
    def square(num1):
        print('The number squared=' , num1**2)
    def sqrt(num1):
        print(f'The square root= {(num1)**.5}')
    def cube(num1):
        print(f'The number cubed= {(num1**3)}')
    def cbrt(num1):
        print(f'The cube root= {num1**(1/3)}')
    def area(num1):
        print(f'The area of the square= {num1*num2}')
    def perim(num1,num2):
        print(f'The perimeter of the square= {num1+num1+num2+num2}')
        
while True:
    print('Choose from the following options: ')
    print('1. Addition')
    print('2. Subtraction')
    print('3. Multiplication')
    print('4. Division')
    print('5. Sin')
    print('6. Cosine')
    print('7. Tangent')
    print('8. Secant')
    print('9. Cosecant')
    print('10. Cotangent')
    print('11. Square')
    print('12. Square root')
    print('13. Cube')
    print('14. Cube root')
    print('15. Find the area of a square')
    print('16. Find the perimeter of a square')
    print('17. End the program')
    
    choice=int(input('Enter your choice (1-16): '))
    
    if choice==1:
        num1=int(input('Enter your first number: '))
        num2=int(input('Enter your second number: '))
        calc.addition(num1,num2)
    
    elif choice==2:
        num1=int(input('Enter your first number: '))
        num2=int(input('Enter your second number: '))
        calc.sub(num1,num2)
    elif choice==3:
        num1=int(input('Enter your first number: '))
        num2=int(input('Enter your second number: '))
        calc.mult(num1,num2)
    elif choice==4:
        num1=int(input('Enter your first number: '))
        num2=int(input('Enter your second number: '))
        if num2==0:
            print('Infinity')
        else:
            calc.div(num1,num2)
    elif choice==5:
        num1=int(input('Enter a number: '))
        calc.sin(num1)
    elif choice==6:
        num1=int(input('Enter a number: '))
        calc.cosine(num1)
    elif choice==7:
        num1=int(input('Enter a number: '))
        calc.tangent(num1)
    elif choice==8:
        num1=int(input('Enter a number: '))
        calc.secant(num1)
    elif choice==9:
        num1=int(input('Enter a number: '))
        calc.cosecant(num1)
    elif choice==10:
        num1=int(input('Enter a number: '))
        calc.cotan(num1)
    elif choice==11:
        num1=int(input('Enter a number: '))
        calc.square(num1)
    elif choice==12:
        num1=int(input('Enter a number: '))
        calc.sqrt(num1)
    elif choice==13:
        num1=int(input('Enter a number: '))
        calc.cube(num1)
    elif choice==14:
        num1=int(input('Enter a number: '))
        calc.cbrt(num1)
    elif choice==15:
        num1=int(input('Enter your first number: '))
        calc.area(num1)
    elif choice==16:
        num1=int(input('Enter your first number: '))
        num2=int(input('Enter your second number: '))
        calc.perim(num1,num2)
        
    elif choice==17:
        break
    else:
        print('Wrong choice')
# Out:
# Choose from the following options:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Sin
# 6. Cosine
# 7. Tangent
# 8. Secant
# 9. Cosecant
# 10. Cotangent
# 11. Square
# 12. Square root
# 13. Cube
# 14. Cube root
# 15. Find the area of a square
# 16. Find the perimeter of a square
# 17. End the program
# Enter your choice (1-16): 4
# Enter your first number: 5
# Enter your second number: 1
# Division= 5.0
# Choose from the following options:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Sin
# 6. Cosine
# 7. Tangent
# 8. Secant
# 9. Cosecant
# 10. Cotangent
# 11. Square
# 12. Square root
# 13. Cube
# 14. Cube root
# 15. Find the area of a square
# 16. Find the perimeter of a square
# 17. End the program
# Enter your choice (1-16): 10
# Enter a number: 17
# The contangent= 0.2862118326454602
# Choose from the following options:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Sin
# 6. Cosine
# 7. Tangent
# 8. Secant
# ...
